# %% [markdown]
# # 데이터 불러오기
# - 데이터 형태는
# - X = (3950, 20)과 같이 (전체 데이터 개수, voca_size)
# - y = (3950,1) 과같이 (전체 데이터 개수, 정수)

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from tensorflow.keras import regularizers

# %%
# 데이터 로드
train_data_path = "./train_general.csv"
train_data = pd.read_csv(train_data_path)

# 클래스 이름
CLASS_NAMES = ['협박 대화', '갈취 대화', '직장 내 괴롭힘 대화', '기타 괴롭힘 대화', '일반 대화']

# 전체 corpus와 클래스 레이블 준비
corpus = train_data["cleaned_conversation"]
labels = train_data['class']

train_data.head()
# Out:
#    idx  class                                       conversation  text_length  \
# 0    0      0  지금 너 스스로를 죽여달라고 애원하는 것인가?\n 아닙니다. 죄송합니다.\n 죽을 ...           52
# 1    1      0  길동경찰서입니다.\n9시 40분 마트에 폭발물을 설치할거다.\n네?\n똑바로 들어 ...           39
# 2    2      3  너 되게 귀여운거 알지? 나보다 작은 남자는 첨봤어.\n그만해. 니들 놀리는거 재미...           52
# 3    3      1  어이 거기\n예??\n너 말이야 너. 이리 오라고\n무슨 일.\n너 옷 좋아보인다?...           34
# 4    4      1  저기요 혹시 날이 너무 뜨겁잖아요? 저희 회사에서 이 선크림 파는데 한 번 손등에 ...          118
#
#    word_count                               cleaned_conversation
# 0          52  지금 너 스스로를 죽여달라고 애원하는 것인가 아닙니다 죄송합니다 죽을 거면 혼자 죽...
# 1          39  길동경찰서입니다 9시 40분 마트에 폭발물을 설치할거다 네 똑바로 들어 한번만 더 ...
# 2          52  너 되게 귀여운거 알지 나보다 작은 남자는 첨봤어 그만해 니들 놀리는거 재미없어 지...
# 3          34  어이 거기 예 너 말이야 너 이리 오라고 무슨 일 너 옷 좋아보인다 얘 돈 좀 있나...
# 4         118  저기요 혹시 날이 너무 뜨겁잖아요 저희 회사에서 이 선크림 파는데 한 번 손등에 발...

# %%
# 토큰화 + encoding 진행 
# 변수 = voca_size, 토큰화 방법

def tokenize(corpus):
    tokenizer = tf.keras.preprocessing.text.Tokenizer(
        num_words=10000, 
        filters=' ',
        oov_token="<unk>")
    tokenizer.fit_on_texts(corpus)
    tensor = tokenizer.texts_to_sequences(corpus)   
    tensor = tf.keras.preprocessing.sequence.pad_sequences(tensor, padding='post', maxlen=100)  
    return tensor, tokenizer

# 토큰화 수행
tensor, tokenizer = tokenize(corpus)

# %%
# (데이터 개수, max_length)
tensor.shape
# Out:
# (4976, 100)

# %%
X_train, X_test, y_train, y_test = train_test_split(tensor, labels, test_size=0.2, stratify=labels)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1, stratify=y_train)

# %%
# 클래스 가중치 계산 (클래스 4 포함)
class_weights = class_weight.compute_class_weight(
    'balanced',
    classes=np.unique(y_train),
    y=y_train
)
class_weights = dict(enumerate(class_weights))

# 각 샘플에 가중치 할당
sample_weights = np.array([class_weights[y] for y in y_train])

# tf.data.Dataset으로 변환 (sample_weight 포함)
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train, sample_weights))
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))

# 데이터셋을 섞고, 배치 처리
train_dataset = train_dataset.cache().shuffle(10000).batch(32).prefetch(tf.data.experimental.AUTOTUNE)
val_dataset = val_dataset.batch(32)

# %% [markdown]
# # 모델

# %%
class PositionalEncoding(tf.keras.layers.Layer):
    def __init__(self, position, d_model):
        super(PositionalEncoding, self).__init__()
        self.pos_encoding = self.positional_encoding(position, d_model)

    def get_angles(self, position, i, d_model):
        angles = 1 / tf.pow(10000, (2 * (i // 2)) / tf.cast(d_model, tf.float32))
        return position * angles

    def positional_encoding(self, position, d_model):
        angle_rads = self.get_angles(
            position=tf.range(position, dtype=tf.float32)[:, tf.newaxis],
            i=tf.range(d_model, dtype=tf.float32)[tf.newaxis, :],
            d_model=d_model)
        sines = tf.math.sin(angle_rads[:, 0::2])
        cosines = tf.math.cos(angle_rads[:, 1::2])
        pos_encoding = tf.stack([sines, cosines], axis=0)
        pos_encoding = tf.transpose(pos_encoding,[1, 2, 0]) 
        pos_encoding = tf.reshape(pos_encoding, [position, d_model])
        pos_encoding = pos_encoding[tf.newaxis, ...]
        return tf.cast(pos_encoding, tf.float32)

    def call(self, inputs):
        return inputs + self.pos_encoding[:, :tf.shape(inputs)[1], :]

# %%
def scaled_dot_product_attention(query, key, value, mask):
    matmul_qk = tf.matmul(query, key, transpose_b=True)
    depth = tf.cast(tf.shape(key)[-1], tf.float32)
    logits = matmul_qk / tf.math.sqrt(depth)
    if mask is not None:
        logits += (mask * -1e9)
    attention_weights = tf.nn.softmax(logits, axis=-1)
    output = tf.matmul(attention_weights, value)
    return output

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
    def __init__(self, d_model, num_heads, name="multi_head_attention"):
        super(MultiHeadAttention, self).__init__(name=name)
        self.num_heads = num_heads
        self.d_model = d_model
        assert d_model % self.num_heads == 0
        self.depth = d_model // self.num_heads
        self.query_dense = tf.keras.layers.Dense(units=d_model)
        self.key_dense = tf.keras.layers.Dense(units=d_model)
        self.value_dense = tf.keras.layers.Dense(units=d_model)
        self.dense = tf.keras.layers.Dense(units=d_model)

    def split_heads(self, inputs, batch_size):
        inputs = tf.reshape(inputs, shape=(batch_size, -1, self.num_heads, self.depth))
        return tf.transpose(inputs, perm=[0, 2, 1, 3])

    def call(self, inputs):
        query, key, value, mask = inputs['query'], inputs['key'], inputs['value'], inputs['mask']
        batch_size = tf.shape(query)[0]
        query = self.query_dense(query)
        key = self.key_dense(key)
        value = self.value_dense(value)
        query = self.split_heads(query, batch_size)
        key = self.split_heads(key, batch_size)
        value = self.split_heads(value, batch_size)
        scaled_attention = scaled_dot_product_attention(query, key, value, mask)
        scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])
        concat_attention = tf.reshape(scaled_attention, (batch_size, -1, self.d_model))
        outputs = self.dense(concat_attention)
        return outputs

# %%
def create_padding_mask(x):
    mask = tf.cast(tf.math.equal(x, 0), tf.float32)
    return mask[:, tf.newaxis, tf.newaxis, :]

# %%
def encoder_layer(units, d_model, num_heads, dropout, name="encoder_layer"):
    inputs = tf.keras.Input(shape=(None, d_model), name="inputs")
    padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")
    attention = MultiHeadAttention(d_model, num_heads, name="attention")({
        'query': inputs,
        'key': inputs,
        'value': inputs,
        'mask': padding_mask
    })
    attention = tf.keras.layers.Dropout(rate=dropout)(attention)
    attention = tf.keras.layers.LayerNormalization(epsilon=1e-6)(inputs + attention)
    outputs = tf.keras.layers.Dense(units=units, activation='relu', kernel_regularizer=regularizers.l2(1e-3))(attention)
    outputs = tf.keras.layers.Dense(units=d_model)(outputs)
    outputs = tf.keras.layers.Dropout(rate=dropout)(outputs)
    outputs = tf.keras.layers.LayerNormalization(epsilon=1e-6)(attention + outputs)
    return tf.keras.Model(inputs=[inputs, padding_mask], outputs=outputs, name=name)

# %%
def encoder(vocab_size, num_layers, units, d_model, num_heads, dropout, name="encoder"):
    inputs = tf.keras.Input(shape=(None,), name="inputs")
    padding_mask = tf.keras.Input(shape=(1, 1, None), name="padding_mask")
    embeddings = tf.keras.layers.Embedding(vocab_size, d_model)(inputs)
    embeddings *= tf.math.sqrt(tf.cast(d_model, tf.float32))
    embeddings = PositionalEncoding(vocab_size, d_model)(embeddings)
    outputs = tf.keras.layers.Dropout(rate=dropout)(embeddings)
    for i in range(num_layers):
        outputs = encoder_layer(units=units, d_model=d_model, num_heads=num_heads, dropout=dropout, name="encoder_layer_{}".format(i))([outputs, padding_mask])
    return tf.keras.Model(inputs=[inputs, padding_mask], outputs=outputs, name=name)

# %%
def transformer(vocab_size, num_layers, units, d_model, num_heads, dropout, name="transformer"):    
    inputs = tf.keras.Input(shape=(None,), name="inputs")
    enc_padding_mask = tf.keras.layers.Lambda(create_padding_mask, output_shape=(1, 1, None), name='enc_padding_mask')(inputs)
    enc_outputs = encoder(vocab_size=vocab_size, num_layers=num_layers, units=units, d_model=d_model, num_heads=num_heads, dropout=dropout)(inputs=[inputs, enc_padding_mask])
    pooled_outputs = tf.keras.layers.GlobalAveragePooling1D()(enc_outputs)
    pooled_outputs = tf.keras.layers.Dropout(rate=dropout)(pooled_outputs)
    outputs = tf.keras.layers.Dense(units=1028, activation='relu', name="linear_hidden_layer")(pooled_outputs)
    outputs = tf.keras.layers.Dense(units=5, activation='softmax', name="outputs")(outputs)
    return tf.keras.Model(inputs=inputs, outputs=outputs, name=name)

# %%
from sklearn.metrics import f1_score
from sklearn.model_selection import ParameterGrid

# 하이퍼파라미터 범위 설정 (탐색할 값들)
param_grid = {
    'D_MODEL': [128, 256, 512],
    'NUM_LAYERS': [1, 2, 3],
    'DROPOUT': [0.1, 0.3, 0.5],
    'UNITS': [128, 256, 512]
}

# 하이퍼파라미터 그리드 생성
grid = ParameterGrid(param_grid)

# 가장 높은 F1-Score 및 최적의 하이퍼파라미터 저장용 변수
best_f1 = 0
best_params = {}

for params in grid:
    print(f"현재 하이퍼파라미터 조합: {params}")
    
    # 모델 생성
    model = transformer(vocab_size=VOCAB_SIZE, 
                        num_layers=params['NUM_LAYERS'], 
                        units=params['UNITS'], 
                        d_model=params['D_MODEL'], 
                        num_heads=NUM_HEADS, 
                        dropout=params['DROPOUT'])
    
    # 모델 컴파일
    learning_rate = CustomSchedule(params['D_MODEL'])
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate, 
                                         beta_1=0.9, beta_2=0.98, epsilon=1e-9)
    model.compile(optimizer=optimizer, loss=loss_function, metrics=[accuracy])

    # 모델 학습
    history = model.fit(train_dataset,
                        validation_data=val_dataset,
                        epochs=10,  # 에폭을 줄여서 빠르게 탐색
                        verbose=1,
                        callbacks=[early_stopping])

    # 테스트 데이터로 예측
    y_pred = model.predict(X_test)
    y_pred = np.argmax(y_pred, axis=1)  # 확률값을 클래스로 변환

    # F1-Score 계산
    f1 = f1_score(y_test, y_pred, average='macro')  # 'macro' 평균 방식 사용
    
    print(f"현재 F1-Score: {f1:.4f}")
    
    # 가장 좋은 F1-Score와 하이퍼파라미터 저장
    if f1 > best_f1:
        best_f1 = f1
        best_params = params

# 최종 결과 출력
print("최고의 F1-Score: {:.4f}".format(best_f1))
print("최적의 하이퍼파라미터:", best_params)
# Out:
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 128, 'NUM_LAYERS': 1, 'UNITS': 128}
# Epoch 1/10
# 112/112 [==============================] - 3s 12ms/step - loss: 1.7386 - accuracy: 0.2219 - val_loss: 1.7098 - val_accuracy: 0.2161
# Epoch 2/10
# 112/112 [==============================] - 1s 9ms/step - loss: 1.6448 - accuracy: 0.3585 - val_loss: 1.4939 - val_accuracy: 0.4523
# Epoch 3/10
# 112/112 [==============================] - 1s 9ms/step - loss: 1.2941 - accuracy: 0.4925 - val_loss: 1.1238 - val_accuracy: 0.5754
# Epoch 4/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.9226 - accuracy: 0.7122 - val_loss: 0.6962 - val_accuracy: 0.8090
# Epoch 5/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.5506 - accuracy: 0.8465 - val_loss: 0.5394 - val_accuracy: 0.8216
# Epoch 6/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.3373 - accuracy: 0.9260 - val_loss: 0.5047 - val_accuracy: 0.8618
# Epoch 7/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.2002 - accuracy: 0.9701 - val_loss: 0.5792 - val_accuracy: 0.8618
# Epoch 8/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.1500 - accuracy: 0.9788 - val_loss: 0.6898 - val_accuracy: 0.8367
# 현재 F1-Score: 0.8708
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 128, 'NUM_LAYERS': 1, 'UNITS': 256}
# Epoch 1/10
# 112/112 [==============================] - 3s 12ms/step - loss: 1.8133 - accuracy: 0.2180 - val_loss: 1.7437 - val_accuracy: 0.3367
# Epoch 2/10
# 112/112 [==============================] - 1s 9ms/step - loss: 1.6824 - accuracy: 0.3548 - val_loss: 1.5387 - val_accuracy: 0.4397
# Epoch 3/10
# 112/112 [==============================] - 1s 9ms/step - loss: 1.3295 - accuracy: 0.5034 - val_loss: 1.2063 - val_accuracy: 0.5251
# Epoch 4/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.9784 - accuracy: 0.6806 - val_loss: 0.7943 - val_accuracy: 0.7387
# Epoch 5/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.6093 - accuracy: 0.8364 - val_loss: 0.6077 - val_accuracy: 0.8266
# Epoch 6/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.3974 - accuracy: 0.9059 - val_loss: 0.6489 - val_accuracy: 0.8166
# Epoch 7/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.2611 - accuracy: 0.9604 - val_loss: 0.7784 - val_accuracy: 0.8241
# 현재 F1-Score: 0.8451
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 128, 'NUM_LAYERS': 1, 'UNITS': 512}
# Epoch 1/10
# 112/112 [==============================] - 3s 12ms/step - loss: 1.8116 - accuracy: 0.2387 - val_loss: 1.7739 - val_accuracy: 0.3668
# Epoch 2/10
# 112/112 [==============================] - 1s 9ms/step - loss: 1.6963 - accuracy: 0.3534 - val_loss: 1.5435 - val_accuracy: 0.4221
# Epoch 3/10
# 112/112 [==============================] - 1s 9ms/step - loss: 1.3316 - accuracy: 0.5380 - val_loss: 1.0983 - val_accuracy: 0.6181
# Epoch 4/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.8814 - accuracy: 0.7487 - val_loss: 0.7599 - val_accuracy: 0.8216
# Epoch 5/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.5717 - accuracy: 0.8596 - val_loss: 0.6542 - val_accuracy: 0.8392
# Epoch 6/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.3895 - accuracy: 0.9241 - val_loss: 0.6758 - val_accuracy: 0.8216
# Epoch 7/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.2630 - accuracy: 0.9648 - val_loss: 0.6598 - val_accuracy: 0.8693
# 현재 F1-Score: 0.8375
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 128, 'NUM_LAYERS': 2, 'UNITS': 128}
# Epoch 1/10
# 112/112 [==============================] - 4s 19ms/step - loss: 1.8524 - accuracy: 0.2568 - val_loss: 1.8026 - val_accuracy: 0.3317
# Epoch 2/10
# 112/112 [==============================] - 2s 14ms/step - loss: 1.7012 - accuracy: 0.3867 - val_loss: 1.4738 - val_accuracy: 0.4648
# Epoch 3/10
# 112/112 [==============================] - 2s 14ms/step - loss: 1.2931 - accuracy: 0.5776 - val_loss: 1.0616 - val_accuracy: 0.6759
# Epoch 4/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.9011 - accuracy: 0.7465 - val_loss: 0.7930 - val_accuracy: 0.7839
# Epoch 5/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.6244 - accuracy: 0.8520 - val_loss: 0.7134 - val_accuracy: 0.8291
# Epoch 6/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.4445 - accuracy: 0.9221 - val_loss: 0.6366 - val_accuracy: 0.8593
# Epoch 7/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.3299 - accuracy: 0.9620 - val_loss: 0.9455 - val_accuracy: 0.7965
# Epoch 8/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.2635 - accuracy: 0.9830 - val_loss: 0.9475 - val_accuracy: 0.8342
# 현재 F1-Score: 0.8651
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 128, 'NUM_LAYERS': 2, 'UNITS': 256}
# Epoch 1/10
# 112/112 [==============================] - 4s 19ms/step - loss: 1.9521 - accuracy: 0.2490 - val_loss: 1.8951 - val_accuracy: 0.3467
# Epoch 2/10
# 112/112 [==============================] - 2s 14ms/step - loss: 1.7974 - accuracy: 0.3624 - val_loss: 1.5545 - val_accuracy: 0.4749
# Epoch 3/10
# 112/112 [==============================] - 2s 14ms/step - loss: 1.3850 - accuracy: 0.5486 - val_loss: 1.1637 - val_accuracy: 0.6533
# Epoch 4/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.9890 - accuracy: 0.7420 - val_loss: 0.8539 - val_accuracy: 0.7864
# Epoch 5/10
# 112/112 [==============================] - 2s 15ms/step - loss: 0.6941 - accuracy: 0.8571 - val_loss: 0.7493 - val_accuracy: 0.8442
# Epoch 6/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.5064 - accuracy: 0.9210 - val_loss: 0.7598 - val_accuracy: 0.8492
# Epoch 7/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.4031 - accuracy: 0.9562 - val_loss: 0.8513 - val_accuracy: 0.8442
# 현재 F1-Score: 0.8391
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 128, 'NUM_LAYERS': 2, 'UNITS': 512}
# Epoch 1/10
# 112/112 [==============================] - 4s 20ms/step - loss: 2.0061 - accuracy: 0.2596 - val_loss: 1.9517 - val_accuracy: 0.3593
# Epoch 2/10
# 112/112 [==============================] - 2s 15ms/step - loss: 1.8183 - accuracy: 0.3992 - val_loss: 1.6306 - val_accuracy: 0.4523
# Epoch 3/10
# 112/112 [==============================] - 2s 15ms/step - loss: 1.4026 - accuracy: 0.5835 - val_loss: 1.1435 - val_accuracy: 0.6935
# Epoch 4/10
# 112/112 [==============================] - 2s 15ms/step - loss: 0.9795 - accuracy: 0.7725 - val_loss: 0.9108 - val_accuracy: 0.7814
# Epoch 5/10
# 112/112 [==============================] - 2s 15ms/step - loss: 0.7042 - accuracy: 0.8777 - val_loss: 0.8055 - val_accuracy: 0.8141
# Epoch 6/10
# 112/112 [==============================] - 2s 15ms/step - loss: 0.5685 - accuracy: 0.9179 - val_loss: 0.7857 - val_accuracy: 0.8241
# Epoch 7/10
# 112/112 [==============================] - 2s 15ms/step - loss: 0.4505 - accuracy: 0.9584 - val_loss: 0.9036 - val_accuracy: 0.8090
# Epoch 8/10
# 112/112 [==============================] - 2s 15ms/step - loss: 0.3644 - accuracy: 0.9777 - val_loss: 0.8916 - val_accuracy: 0.8367
# 현재 F1-Score: 0.8586
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 128, 'NUM_LAYERS': 3, 'UNITS': 128}
# Epoch 1/10
# 112/112 [==============================] - 6s 26ms/step - loss: 2.0216 - accuracy: 0.2501 - val_loss: 1.9072 - val_accuracy: 0.3518
# Epoch 2/10
# 112/112 [==============================] - 2s 19ms/step - loss: 1.7627 - accuracy: 0.3903 - val_loss: 1.5450 - val_accuracy: 0.4925
# Epoch 3/10
# 112/112 [==============================] - 2s 19ms/step - loss: 1.3904 - accuracy: 0.5731 - val_loss: 1.1742 - val_accuracy: 0.6834
# Epoch 4/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.0152 - accuracy: 0.7379 - val_loss: 0.9136 - val_accuracy: 0.7915
# Epoch 5/10
# 112/112 [==============================] - 2s 19ms/step - loss: 0.7349 - accuracy: 0.8590 - val_loss: 0.9722 - val_accuracy: 0.7864
# Epoch 6/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.5673 - accuracy: 0.9146 - val_loss: 1.0264 - val_accuracy: 0.7764
# 현재 F1-Score: 0.8023
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 128, 'NUM_LAYERS': 3, 'UNITS': 256}
# Epoch 1/10
# 112/112 [==============================] - 6s 26ms/step - loss: 2.1303 - accuracy: 0.2186 - val_loss: 2.0664 - val_accuracy: 0.3015
# Epoch 2/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.8963 - accuracy: 0.3978 - val_loss: 1.6532 - val_accuracy: 0.4472
# Epoch 3/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.4913 - accuracy: 0.5810 - val_loss: 1.2083 - val_accuracy: 0.7186
# Epoch 4/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.1359 - accuracy: 0.7395 - val_loss: 1.1440 - val_accuracy: 0.7337
# Epoch 5/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.8600 - accuracy: 0.8518 - val_loss: 0.9926 - val_accuracy: 0.8116
# Epoch 6/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.6715 - accuracy: 0.9165 - val_loss: 0.9982 - val_accuracy: 0.8266
# Epoch 7/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.5838 - accuracy: 0.9419 - val_loss: 0.9721 - val_accuracy: 0.8342
# Epoch 8/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.4766 - accuracy: 0.9732 - val_loss: 0.9822 - val_accuracy: 0.8568
# Epoch 9/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.4241 - accuracy: 0.9807 - val_loss: 0.9423 - val_accuracy: 0.8442
# Epoch 10/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.4155 - accuracy: 0.9707 - val_loss: 1.2468 - val_accuracy: 0.8216
# 현재 F1-Score: 0.8169
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 128, 'NUM_LAYERS': 3, 'UNITS': 512}
# Epoch 1/10
# 112/112 [==============================] - 6s 28ms/step - loss: 2.2141 - accuracy: 0.2580 - val_loss: 2.1215 - val_accuracy: 0.3317
# Epoch 2/10
# 112/112 [==============================] - 2s 21ms/step - loss: 1.9351 - accuracy: 0.4146 - val_loss: 1.7363 - val_accuracy: 0.4975
# Epoch 3/10
# 112/112 [==============================] - 2s 21ms/step - loss: 1.5390 - accuracy: 0.5983 - val_loss: 1.3386 - val_accuracy: 0.6884
# Epoch 4/10
# 112/112 [==============================] - 2s 21ms/step - loss: 1.1698 - accuracy: 0.7613 - val_loss: 1.0748 - val_accuracy: 0.7839
# Epoch 5/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.9223 - accuracy: 0.8481 - val_loss: 1.1616 - val_accuracy: 0.7814
# Epoch 6/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.7561 - accuracy: 0.9149 - val_loss: 0.9750 - val_accuracy: 0.8543
# Epoch 7/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.6227 - accuracy: 0.9453 - val_loss: 0.9556 - val_accuracy: 0.8593
# Epoch 8/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.5146 - accuracy: 0.9732 - val_loss: 1.1066 - val_accuracy: 0.8342
# Epoch 9/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.4760 - accuracy: 0.9732 - val_loss: 1.0433 - val_accuracy: 0.8568
# 현재 F1-Score: 0.8539
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 256, 'NUM_LAYERS': 1, 'UNITS': 128}
# Epoch 1/10
# 112/112 [==============================] - 3s 15ms/step - loss: 1.7722 - accuracy: 0.2493 - val_loss: 1.7133 - val_accuracy: 0.3467
# Epoch 2/10
# 112/112 [==============================] - 1s 11ms/step - loss: 1.6272 - accuracy: 0.3825 - val_loss: 1.4417 - val_accuracy: 0.4397
# Epoch 3/10
# 112/112 [==============================] - 1s 11ms/step - loss: 1.2247 - accuracy: 0.5717 - val_loss: 0.9827 - val_accuracy: 0.6884
# Epoch 4/10
# 112/112 [==============================] - 1s 11ms/step - loss: 0.8575 - accuracy: 0.7365 - val_loss: 0.7118 - val_accuracy: 0.8015
# Epoch 5/10
# 112/112 [==============================] - 1s 11ms/step - loss: 0.5206 - accuracy: 0.8766 - val_loss: 0.5449 - val_accuracy: 0.8467
# Epoch 6/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.3413 - accuracy: 0.9336 - val_loss: 0.7998 - val_accuracy: 0.8015
# Epoch 7/10
# 112/112 [==============================] - 1s 11ms/step - loss: 0.2149 - accuracy: 0.9796 - val_loss: 0.6411 - val_accuracy: 0.8769
# 현재 F1-Score: 0.8488
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 256, 'NUM_LAYERS': 1, 'UNITS': 256}
# Epoch 1/10
# 112/112 [==============================] - 3s 15ms/step - loss: 1.8894 - accuracy: 0.2289 - val_loss: 1.8053 - val_accuracy: 0.3241
# Epoch 2/10
# 112/112 [==============================] - 1s 12ms/step - loss: 1.7217 - accuracy: 0.3788 - val_loss: 1.5606 - val_accuracy: 0.4698
# Epoch 3/10
# 112/112 [==============================] - 1s 12ms/step - loss: 1.2931 - accuracy: 0.5963 - val_loss: 1.0155 - val_accuracy: 0.7060
# Epoch 4/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.8799 - accuracy: 0.7610 - val_loss: 0.7483 - val_accuracy: 0.8191
# Epoch 5/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.5880 - accuracy: 0.8660 - val_loss: 0.6375 - val_accuracy: 0.8492
# Epoch 6/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.4039 - accuracy: 0.9391 - val_loss: 0.6417 - val_accuracy: 0.8492
# Epoch 7/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.2878 - accuracy: 0.9752 - val_loss: 0.6381 - val_accuracy: 0.8668
# 현재 F1-Score: 0.8496
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 256, 'NUM_LAYERS': 1, 'UNITS': 512}
# Epoch 1/10
# 112/112 [==============================] - 3s 16ms/step - loss: 1.9701 - accuracy: 0.2412 - val_loss: 1.8681 - val_accuracy: 0.4146
# Epoch 2/10
# 112/112 [==============================] - 1s 12ms/step - loss: 1.7588 - accuracy: 0.4193 - val_loss: 1.5375 - val_accuracy: 0.4874
# Epoch 3/10
# 112/112 [==============================] - 1s 12ms/step - loss: 1.2903 - accuracy: 0.6245 - val_loss: 1.0826 - val_accuracy: 0.6859
# Epoch 4/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.9376 - accuracy: 0.7649 - val_loss: 0.7919 - val_accuracy: 0.8417
# Epoch 5/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.6528 - accuracy: 0.8758 - val_loss: 0.7081 - val_accuracy: 0.8618
# Epoch 6/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.4796 - accuracy: 0.9358 - val_loss: 0.7025 - val_accuracy: 0.8643
# Epoch 7/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.3528 - accuracy: 0.9752 - val_loss: 0.7766 - val_accuracy: 0.8593
# Epoch 8/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.2879 - accuracy: 0.9844 - val_loss: 0.9247 - val_accuracy: 0.8668
# 현재 F1-Score: 0.8466
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 256, 'NUM_LAYERS': 2, 'UNITS': 128}
# Epoch 1/10
# 112/112 [==============================] - 5s 24ms/step - loss: 1.9660 - accuracy: 0.2582 - val_loss: 1.8668 - val_accuracy: 0.2915
# Epoch 2/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.7213 - accuracy: 0.4098 - val_loss: 1.4633 - val_accuracy: 0.5377
# Epoch 3/10
# 112/112 [==============================] - 2s 19ms/step - loss: 1.2384 - accuracy: 0.6438 - val_loss: 1.0578 - val_accuracy: 0.7211
# Epoch 4/10
# 112/112 [==============================] - 2s 19ms/step - loss: 0.9042 - accuracy: 0.7808 - val_loss: 0.8135 - val_accuracy: 0.8241
# Epoch 5/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.6451 - accuracy: 0.8869 - val_loss: 0.7412 - val_accuracy: 0.8417
# Epoch 6/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.4793 - accuracy: 0.9389 - val_loss: 0.9312 - val_accuracy: 0.8266
# Epoch 7/10
# 112/112 [==============================] - 2s 19ms/step - loss: 0.3804 - accuracy: 0.9701 - val_loss: 0.9202 - val_accuracy: 0.8342
# 현재 F1-Score: 0.8492
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 256, 'NUM_LAYERS': 2, 'UNITS': 256}
# Epoch 1/10
# 112/112 [==============================] - 5s 25ms/step - loss: 2.0986 - accuracy: 0.2635 - val_loss: 1.9908 - val_accuracy: 0.3719
# Epoch 2/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.8508 - accuracy: 0.4422 - val_loss: 1.5516 - val_accuracy: 0.6055
# Epoch 3/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.3717 - accuracy: 0.6563 - val_loss: 1.1806 - val_accuracy: 0.7462
# Epoch 4/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.0212 - accuracy: 0.7965 - val_loss: 0.9520 - val_accuracy: 0.8367
# Epoch 5/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.7667 - accuracy: 0.8914 - val_loss: 1.0372 - val_accuracy: 0.8040
# Epoch 6/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.6061 - accuracy: 0.9447 - val_loss: 1.1718 - val_accuracy: 0.7940
# 현재 F1-Score: 0.8431
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 256, 'NUM_LAYERS': 2, 'UNITS': 512}
# Epoch 1/10
# 112/112 [==============================] - 5s 26ms/step - loss: 2.3246 - accuracy: 0.2353 - val_loss: 2.1859 - val_accuracy: 0.3467
# Epoch 2/10
# 112/112 [==============================] - 2s 21ms/step - loss: 2.0134 - accuracy: 0.4442 - val_loss: 1.6979 - val_accuracy: 0.6005
# Epoch 3/10
# 112/112 [==============================] - 2s 22ms/step - loss: 1.5378 - accuracy: 0.6452 - val_loss: 1.3705 - val_accuracy: 0.7362
# Epoch 4/10
# 112/112 [==============================] - 2s 21ms/step - loss: 1.1683 - accuracy: 0.8018 - val_loss: 1.2668 - val_accuracy: 0.7688
# Epoch 5/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.9289 - accuracy: 0.8886 - val_loss: 1.0414 - val_accuracy: 0.8392
# Epoch 6/10
# 112/112 [==============================] - 2s 22ms/step - loss: 0.7538 - accuracy: 0.9417 - val_loss: 1.4412 - val_accuracy: 0.7638
# Epoch 7/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.6446 - accuracy: 0.9668 - val_loss: 1.1356 - val_accuracy: 0.8291
# 현재 F1-Score: 0.8551
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 256, 'NUM_LAYERS': 3, 'UNITS': 128}
# Epoch 1/10
# 112/112 [==============================] - 7s 33ms/step - loss: 2.1008 - accuracy: 0.2700 - val_loss: 1.9673 - val_accuracy: 0.4070
# Epoch 2/10
# 112/112 [==============================] - 3s 27ms/step - loss: 1.7691 - accuracy: 0.4899 - val_loss: 1.4318 - val_accuracy: 0.6432
# Epoch 3/10
# 112/112 [==============================] - 3s 27ms/step - loss: 1.2875 - accuracy: 0.6873 - val_loss: 1.1637 - val_accuracy: 0.7337
# Epoch 4/10
# 112/112 [==============================] - 3s 27ms/step - loss: 0.9886 - accuracy: 0.8116 - val_loss: 0.9324 - val_accuracy: 0.8342
# Epoch 5/10
# 112/112 [==============================] - 3s 27ms/step - loss: 0.8024 - accuracy: 0.8841 - val_loss: 0.8798 - val_accuracy: 0.8543
# Epoch 6/10
# 112/112 [==============================] - 3s 27ms/step - loss: 0.6320 - accuracy: 0.9458 - val_loss: 1.1640 - val_accuracy: 0.7915
# Epoch 7/10
# 112/112 [==============================] - 3s 27ms/step - loss: 0.5523 - accuracy: 0.9640 - val_loss: 1.0907 - val_accuracy: 0.8216
# 현재 F1-Score: 0.8493
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 256, 'NUM_LAYERS': 3, 'UNITS': 256}
# Epoch 1/10
# 112/112 [==============================] - 7s 35ms/step - loss: 2.3464 - accuracy: 0.2658 - val_loss: 2.2096 - val_accuracy: 0.3543
# Epoch 2/10
# 112/112 [==============================] - 3s 28ms/step - loss: 2.0294 - accuracy: 0.4503 - val_loss: 1.7109 - val_accuracy: 0.6256
# Epoch 3/10
# 112/112 [==============================] - 3s 28ms/step - loss: 1.5968 - accuracy: 0.6591 - val_loss: 1.5116 - val_accuracy: 0.6633
# Epoch 4/10
# 112/112 [==============================] - 3s 28ms/step - loss: 1.2942 - accuracy: 0.7800 - val_loss: 1.2091 - val_accuracy: 0.8116
# Epoch 5/10
# 112/112 [==============================] - 3s 29ms/step - loss: 1.0392 - accuracy: 0.8827 - val_loss: 1.1942 - val_accuracy: 0.8492
# Epoch 6/10
# 112/112 [==============================] - 3s 28ms/step - loss: 0.8499 - accuracy: 0.9394 - val_loss: 1.2328 - val_accuracy: 0.8417
# Epoch 7/10
# 112/112 [==============================] - 3s 28ms/step - loss: 0.7600 - accuracy: 0.9576 - val_loss: 1.2135 - val_accuracy: 0.8794
# 현재 F1-Score: 0.8369
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 256, 'NUM_LAYERS': 3, 'UNITS': 512}
# Epoch 1/10
# 112/112 [==============================] - 7s 37ms/step - loss: 2.6218 - accuracy: 0.2607 - val_loss: 2.4661 - val_accuracy: 0.3819
# Epoch 2/10
# 112/112 [==============================] - 3s 31ms/step - loss: 2.2747 - accuracy: 0.4461 - val_loss: 2.0892 - val_accuracy: 0.4975
# Epoch 3/10
# 112/112 [==============================] - 3s 30ms/step - loss: 1.8334 - accuracy: 0.6605 - val_loss: 1.6071 - val_accuracy: 0.7739
# Epoch 4/10
# 112/112 [==============================] - 3s 31ms/step - loss: 1.5159 - accuracy: 0.7814 - val_loss: 1.4773 - val_accuracy: 0.7789
# Epoch 5/10
# 112/112 [==============================] - 3s 31ms/step - loss: 1.2609 - accuracy: 0.8755 - val_loss: 1.4636 - val_accuracy: 0.8040
# Epoch 6/10
# 112/112 [==============================] - 3s 31ms/step - loss: 1.0828 - accuracy: 0.9249 - val_loss: 1.3581 - val_accuracy: 0.8467
# Epoch 7/10
# 112/112 [==============================] - 3s 31ms/step - loss: 0.9644 - accuracy: 0.9489 - val_loss: 1.3883 - val_accuracy: 0.8191
# Epoch 8/10
# 112/112 [==============================] - 3s 31ms/step - loss: 0.8679 - accuracy: 0.9659 - val_loss: 1.2795 - val_accuracy: 0.8492
# Epoch 9/10
# 112/112 [==============================] - 3s 31ms/step - loss: 0.7686 - accuracy: 0.9791 - val_loss: 1.6049 - val_accuracy: 0.8090
# Epoch 10/10
# 112/112 [==============================] - 3s 31ms/step - loss: 0.6811 - accuracy: 0.9791 - val_loss: 1.2383 - val_accuracy: 0.8543
# 현재 F1-Score: 0.8390
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 512, 'NUM_LAYERS': 1, 'UNITS': 128}
# Epoch 1/10
# 112/112 [==============================] - 4s 23ms/step - loss: 1.8069 - accuracy: 0.2764 - val_loss: 1.6888 - val_accuracy: 0.3643
# Epoch 2/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.5003 - accuracy: 0.4841 - val_loss: 1.1859 - val_accuracy: 0.5879
# Epoch 3/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.0644 - accuracy: 0.6672 - val_loss: 0.9091 - val_accuracy: 0.7161
# Epoch 4/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.7820 - accuracy: 0.7831 - val_loss: 0.7890 - val_accuracy: 0.7588
# Epoch 5/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.5321 - accuracy: 0.8811 - val_loss: 0.6052 - val_accuracy: 0.8543
# Epoch 6/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.3413 - accuracy: 0.9500 - val_loss: 0.6506 - val_accuracy: 0.8568
# Epoch 7/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.2650 - accuracy: 0.9690 - val_loss: 0.7318 - val_accuracy: 0.8367
# 현재 F1-Score: 0.8538
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 512, 'NUM_LAYERS': 1, 'UNITS': 256}
# Epoch 1/10
# 112/112 [==============================] - 4s 24ms/step - loss: 1.9453 - accuracy: 0.2644 - val_loss: 1.8030 - val_accuracy: 0.4171
# Epoch 2/10
# 112/112 [==============================] - 2s 21ms/step - loss: 1.6044 - accuracy: 0.4821 - val_loss: 1.3185 - val_accuracy: 0.6281
# Epoch 3/10
# 112/112 [==============================] - 2s 21ms/step - loss: 1.2171 - accuracy: 0.6516 - val_loss: 1.0363 - val_accuracy: 0.7186
# Epoch 4/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.9378 - accuracy: 0.7686 - val_loss: 0.8638 - val_accuracy: 0.7889
# Epoch 5/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.6715 - accuracy: 0.8763 - val_loss: 0.8027 - val_accuracy: 0.8065
# Epoch 6/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.4873 - accuracy: 0.9422 - val_loss: 0.8294 - val_accuracy: 0.8166
# Epoch 7/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.3611 - accuracy: 0.9782 - val_loss: 0.8808 - val_accuracy: 0.8291
# 현재 F1-Score: 0.8367
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 512, 'NUM_LAYERS': 1, 'UNITS': 512}
# Epoch 1/10
# 112/112 [==============================] - 4s 25ms/step - loss: 2.0930 - accuracy: 0.2744 - val_loss: 1.9678 - val_accuracy: 0.3643
# Epoch 2/10
# 112/112 [==============================] - 2s 22ms/step - loss: 1.7318 - accuracy: 0.5235 - val_loss: 1.4221 - val_accuracy: 0.6382
# Epoch 3/10
# 112/112 [==============================] - 2s 22ms/step - loss: 1.3273 - accuracy: 0.6750 - val_loss: 1.2089 - val_accuracy: 0.7286
# Epoch 4/10
# 112/112 [==============================] - 2s 22ms/step - loss: 1.0607 - accuracy: 0.7836 - val_loss: 1.0282 - val_accuracy: 0.7915
# Epoch 5/10
# 112/112 [==============================] - 2s 22ms/step - loss: 0.8077 - accuracy: 0.8794 - val_loss: 0.9476 - val_accuracy: 0.8216
# Epoch 6/10
# 112/112 [==============================] - 2s 22ms/step - loss: 0.6178 - accuracy: 0.9377 - val_loss: 1.0491 - val_accuracy: 0.8141
# Epoch 7/10
# 112/112 [==============================] - 2s 22ms/step - loss: 0.5027 - accuracy: 0.9704 - val_loss: 1.0816 - val_accuracy: 0.8266
# 현재 F1-Score: 0.8342
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 512, 'NUM_LAYERS': 2, 'UNITS': 128}
# Epoch 1/10
# 112/112 [==============================] - 7s 39ms/step - loss: 1.9911 - accuracy: 0.2825 - val_loss: 1.8035 - val_accuracy: 0.4095
# Epoch 2/10
# 112/112 [==============================] - 4s 35ms/step - loss: 1.5884 - accuracy: 0.5081 - val_loss: 1.2510 - val_accuracy: 0.6935
# Epoch 3/10
# 112/112 [==============================] - 4s 35ms/step - loss: 1.1528 - accuracy: 0.7077 - val_loss: 0.9736 - val_accuracy: 0.8015
# Epoch 4/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.8635 - accuracy: 0.8252 - val_loss: 0.8439 - val_accuracy: 0.8417
# Epoch 5/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.6462 - accuracy: 0.9129 - val_loss: 0.9872 - val_accuracy: 0.8040
# Epoch 6/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.5112 - accuracy: 0.9556 - val_loss: 0.8493 - val_accuracy: 0.8568
# 현재 F1-Score: 0.8411
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 512, 'NUM_LAYERS': 2, 'UNITS': 256}
# Epoch 1/10
# 112/112 [==============================] - 7s 41ms/step - loss: 2.2428 - accuracy: 0.2881 - val_loss: 2.1127 - val_accuracy: 0.3367
# Epoch 2/10
# 112/112 [==============================] - 4s 36ms/step - loss: 1.8314 - accuracy: 0.5366 - val_loss: 1.5228 - val_accuracy: 0.6658
# Epoch 3/10
# 112/112 [==============================] - 4s 36ms/step - loss: 1.4329 - accuracy: 0.7055 - val_loss: 1.2582 - val_accuracy: 0.7638
# Epoch 4/10
# 112/112 [==============================] - 4s 36ms/step - loss: 1.1417 - accuracy: 0.8169 - val_loss: 1.1990 - val_accuracy: 0.8141
# Epoch 5/10
# 112/112 [==============================] - 4s 36ms/step - loss: 0.8869 - accuracy: 0.9165 - val_loss: 1.0715 - val_accuracy: 0.8367
# Epoch 6/10
# 112/112 [==============================] - 4s 36ms/step - loss: 0.7355 - accuracy: 0.9606 - val_loss: 1.2115 - val_accuracy: 0.8090
# Epoch 7/10
# 112/112 [==============================] - 4s 36ms/step - loss: 0.6480 - accuracy: 0.9768 - val_loss: 1.1460 - val_accuracy: 0.8543
# 현재 F1-Score: 0.8439
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 512, 'NUM_LAYERS': 2, 'UNITS': 512}
# Epoch 1/10
# 112/112 [==============================] - 7s 43ms/step - loss: 2.6147 - accuracy: 0.2747 - val_loss: 2.4110 - val_accuracy: 0.4472
# Epoch 2/10
# 112/112 [==============================] - 4s 39ms/step - loss: 2.1583 - accuracy: 0.5427 - val_loss: 1.8437 - val_accuracy: 0.6382
# Epoch 3/10
# 112/112 [==============================] - 4s 39ms/step - loss: 1.7132 - accuracy: 0.7183 - val_loss: 1.5662 - val_accuracy: 0.7764
# Epoch 4/10
# 112/112 [==============================] - 4s 39ms/step - loss: 1.4270 - accuracy: 0.8303 - val_loss: 1.4109 - val_accuracy: 0.8241
# Epoch 5/10
# 112/112 [==============================] - 4s 39ms/step - loss: 1.1902 - accuracy: 0.9143 - val_loss: 1.4398 - val_accuracy: 0.8166
# Epoch 6/10
# 112/112 [==============================] - 4s 39ms/step - loss: 1.0464 - accuracy: 0.9486 - val_loss: 1.4180 - val_accuracy: 0.8392
# 현재 F1-Score: 0.8170
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 512, 'NUM_LAYERS': 3, 'UNITS': 128}
# Epoch 1/10
# 112/112 [==============================] - 10s 55ms/step - loss: 2.1846 - accuracy: 0.2864 - val_loss: 1.9841 - val_accuracy: 0.4070
# Epoch 2/10
# 112/112 [==============================] - 6s 50ms/step - loss: 1.7139 - accuracy: 0.5519 - val_loss: 1.4016 - val_accuracy: 0.6910
# Epoch 3/10
# 112/112 [==============================] - 6s 50ms/step - loss: 1.3024 - accuracy: 0.7281 - val_loss: 1.2034 - val_accuracy: 0.7764
# Epoch 4/10
# 112/112 [==============================] - 6s 50ms/step - loss: 1.0306 - accuracy: 0.8370 - val_loss: 1.1771 - val_accuracy: 0.8090
# Epoch 5/10
# 112/112 [==============================] - 6s 50ms/step - loss: 0.8263 - accuracy: 0.9154 - val_loss: 1.0861 - val_accuracy: 0.8342
# Epoch 6/10
# 112/112 [==============================] - 6s 50ms/step - loss: 0.6841 - accuracy: 0.9576 - val_loss: 1.1351 - val_accuracy: 0.8442
# Epoch 7/10
# 112/112 [==============================] - 6s 50ms/step - loss: 0.6054 - accuracy: 0.9782 - val_loss: 1.1752 - val_accuracy: 0.8291
# 현재 F1-Score: 0.8299
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 512, 'NUM_LAYERS': 3, 'UNITS': 256}
# Epoch 1/10
# 112/112 [==============================] - 9s 57ms/step - loss: 2.5905 - accuracy: 0.2915 - val_loss: 2.3956 - val_accuracy: 0.3894
# Epoch 2/10
# 112/112 [==============================] - 6s 52ms/step - loss: 2.1214 - accuracy: 0.5511 - val_loss: 1.8214 - val_accuracy: 0.6834
# Epoch 3/10
# 112/112 [==============================] - 6s 52ms/step - loss: 1.7090 - accuracy: 0.7239 - val_loss: 1.6147 - val_accuracy: 0.7714
# Epoch 4/10
# 112/112 [==============================] - 6s 52ms/step - loss: 1.4630 - accuracy: 0.8233 - val_loss: 1.5921 - val_accuracy: 0.7864
# Epoch 5/10
# 112/112 [==============================] - 6s 52ms/step - loss: 1.2122 - accuracy: 0.9087 - val_loss: 1.4361 - val_accuracy: 0.8342
# Epoch 6/10
# 112/112 [==============================] - 6s 52ms/step - loss: 1.0788 - accuracy: 0.9475 - val_loss: 1.5989 - val_accuracy: 0.8015
# Epoch 7/10
# 112/112 [==============================] - 6s 52ms/step - loss: 0.9882 - accuracy: 0.9643 - val_loss: 1.6043 - val_accuracy: 0.8291
# 현재 F1-Score: 0.8545
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.1, 'D_MODEL': 512, 'NUM_LAYERS': 3, 'UNITS': 512}
# Epoch 1/10
# 112/112 [==============================] - 10s 62ms/step - loss: 3.0895 - accuracy: 0.2806 - val_loss: 2.8591 - val_accuracy: 0.4899
# Epoch 2/10
# 112/112 [==============================] - 6s 56ms/step - loss: 2.6252 - accuracy: 0.5461 - val_loss: 2.3190 - val_accuracy: 0.6558
# Epoch 3/10
# 112/112 [==============================] - 6s 56ms/step - loss: 2.2330 - accuracy: 0.7091 - val_loss: 2.1504 - val_accuracy: 0.7236
# Epoch 4/10
# 112/112 [==============================] - 6s 56ms/step - loss: 1.9217 - accuracy: 0.8275 - val_loss: 1.9933 - val_accuracy: 0.7889
# Epoch 5/10
# 112/112 [==============================] - 6s 56ms/step - loss: 1.6806 - accuracy: 0.9068 - val_loss: 1.8622 - val_accuracy: 0.8291
# Epoch 6/10
# 112/112 [==============================] - 6s 56ms/step - loss: 1.5346 - accuracy: 0.9411 - val_loss: 1.9272 - val_accuracy: 0.8266
# Epoch 7/10
# 112/112 [==============================] - 6s 56ms/step - loss: 1.3829 - accuracy: 0.9696 - val_loss: 1.9602 - val_accuracy: 0.8241
# 현재 F1-Score: 0.8577
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.3, 'D_MODEL': 128, 'NUM_LAYERS': 1, 'UNITS': 128}
# Epoch 1/10
# 112/112 [==============================] - 3s 12ms/step - loss: 1.7410 - accuracy: 0.2253 - val_loss: 1.7052 - val_accuracy: 0.2286
# Epoch 2/10
# 112/112 [==============================] - 1s 9ms/step - loss: 1.6883 - accuracy: 0.2811 - val_loss: 1.5903 - val_accuracy: 0.3794
# Epoch 3/10
# 112/112 [==============================] - 1s 9ms/step - loss: 1.4422 - accuracy: 0.4403 - val_loss: 1.2307 - val_accuracy: 0.4724
# Epoch 4/10
# 112/112 [==============================] - 1s 9ms/step - loss: 1.1122 - accuracy: 0.5997 - val_loss: 0.8691 - val_accuracy: 0.7211
# Epoch 5/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.8160 - accuracy: 0.7284 - val_loss: 0.6935 - val_accuracy: 0.8065
# Epoch 6/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.5674 - accuracy: 0.8364 - val_loss: 0.6137 - val_accuracy: 0.8241
# Epoch 7/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.3985 - accuracy: 0.9006 - val_loss: 0.6212 - val_accuracy: 0.8317
# Epoch 8/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.2978 - accuracy: 0.9330 - val_loss: 0.6370 - val_accuracy: 0.8618
# 현재 F1-Score: 0.8317
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.3, 'D_MODEL': 128, 'NUM_LAYERS': 1, 'UNITS': 256}
# Epoch 1/10
# 112/112 [==============================] - 3s 16ms/step - loss: 1.8048 - accuracy: 0.2155 - val_loss: 1.7487 - val_accuracy: 0.3342
# Epoch 2/10
# 112/112 [==============================] - 1s 9ms/step - loss: 1.7225 - accuracy: 0.3012 - val_loss: 1.6003 - val_accuracy: 0.4171
# Epoch 3/10
# 112/112 [==============================] - 1s 9ms/step - loss: 1.4698 - accuracy: 0.4408 - val_loss: 1.2322 - val_accuracy: 0.5000
# Epoch 4/10
# 112/112 [==============================] - 1s 9ms/step - loss: 1.1242 - accuracy: 0.5997 - val_loss: 0.8900 - val_accuracy: 0.7085
# Epoch 5/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.8453 - accuracy: 0.7245 - val_loss: 0.7675 - val_accuracy: 0.7688
# Epoch 6/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.6235 - accuracy: 0.8314 - val_loss: 0.6058 - val_accuracy: 0.8367
# Epoch 7/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.4380 - accuracy: 0.8894 - val_loss: 0.5635 - val_accuracy: 0.8492
# Epoch 8/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.3260 - accuracy: 0.9333 - val_loss: 0.6269 - val_accuracy: 0.8342
# Epoch 9/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.2423 - accuracy: 0.9525 - val_loss: 0.8940 - val_accuracy: 0.8141
# 현재 F1-Score: 0.8564
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.3, 'D_MODEL': 128, 'NUM_LAYERS': 1, 'UNITS': 512}
# Epoch 1/10
# 112/112 [==============================] - 3s 12ms/step - loss: 1.8299 - accuracy: 0.2049 - val_loss: 1.7959 - val_accuracy: 0.2211
# Epoch 2/10
# 112/112 [==============================] - 1s 9ms/step - loss: 1.7648 - accuracy: 0.2965 - val_loss: 1.6500 - val_accuracy: 0.3869
# Epoch 3/10
# 112/112 [==============================] - 1s 9ms/step - loss: 1.5215 - accuracy: 0.4492 - val_loss: 1.2883 - val_accuracy: 0.5151
# Epoch 4/10
# 112/112 [==============================] - 1s 9ms/step - loss: 1.1636 - accuracy: 0.5955 - val_loss: 0.9415 - val_accuracy: 0.6985
# Epoch 5/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.8367 - accuracy: 0.7365 - val_loss: 0.7834 - val_accuracy: 0.7663
# Epoch 6/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.6299 - accuracy: 0.8236 - val_loss: 0.6435 - val_accuracy: 0.8166
# Epoch 7/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.4413 - accuracy: 0.8961 - val_loss: 0.7089 - val_accuracy: 0.8442
# Epoch 8/10
# 112/112 [==============================] - 1s 9ms/step - loss: 0.3287 - accuracy: 0.9352 - val_loss: 0.7448 - val_accuracy: 0.8492
# 현재 F1-Score: 0.8261
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.3, 'D_MODEL': 128, 'NUM_LAYERS': 2, 'UNITS': 128}
# Epoch 1/10
# 112/112 [==============================] - 4s 19ms/step - loss: 1.8761 - accuracy: 0.2099 - val_loss: 1.8389 - val_accuracy: 0.2613
# Epoch 2/10
# 112/112 [==============================] - 2s 14ms/step - loss: 1.8097 - accuracy: 0.2889 - val_loss: 1.6858 - val_accuracy: 0.4246
# Epoch 3/10
# 112/112 [==============================] - 2s 14ms/step - loss: 1.5274 - accuracy: 0.4302 - val_loss: 1.3054 - val_accuracy: 0.5251
# Epoch 4/10
# 112/112 [==============================] - 2s 14ms/step - loss: 1.2136 - accuracy: 0.5838 - val_loss: 1.0009 - val_accuracy: 0.6910
# Epoch 5/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.9145 - accuracy: 0.7314 - val_loss: 0.7812 - val_accuracy: 0.8266
# Epoch 6/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.7049 - accuracy: 0.8146 - val_loss: 0.7492 - val_accuracy: 0.8040
# Epoch 7/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.5471 - accuracy: 0.8788 - val_loss: 0.7284 - val_accuracy: 0.8417
# Epoch 8/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.4097 - accuracy: 0.9257 - val_loss: 0.6849 - val_accuracy: 0.8769
# Epoch 9/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.3316 - accuracy: 0.9523 - val_loss: 0.7543 - val_accuracy: 0.8693
# Epoch 10/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.2801 - accuracy: 0.9626 - val_loss: 0.8145 - val_accuracy: 0.8618
# 현재 F1-Score: 0.8593
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.3, 'D_MODEL': 128, 'NUM_LAYERS': 2, 'UNITS': 256}
# Epoch 1/10
# 112/112 [==============================] - 5s 19ms/step - loss: 1.9732 - accuracy: 0.2060 - val_loss: 1.9258 - val_accuracy: 0.2638
# Epoch 2/10
# 112/112 [==============================] - 2s 14ms/step - loss: 1.8726 - accuracy: 0.3082 - val_loss: 1.6878 - val_accuracy: 0.4020
# Epoch 3/10
# 112/112 [==============================] - 2s 15ms/step - loss: 1.5475 - accuracy: 0.4673 - val_loss: 1.3153 - val_accuracy: 0.6206
# Epoch 4/10
# 112/112 [==============================] - 2s 14ms/step - loss: 1.1956 - accuracy: 0.6415 - val_loss: 0.9948 - val_accuracy: 0.7312
# Epoch 5/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.9017 - accuracy: 0.7708 - val_loss: 0.8709 - val_accuracy: 0.8065
# Epoch 6/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.7203 - accuracy: 0.8423 - val_loss: 0.8004 - val_accuracy: 0.8392
# Epoch 7/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.5787 - accuracy: 0.8875 - val_loss: 0.7782 - val_accuracy: 0.8442
# Epoch 8/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.4578 - accuracy: 0.9291 - val_loss: 0.9105 - val_accuracy: 0.8216
# Epoch 9/10
# 112/112 [==============================] - 2s 14ms/step - loss: 0.3700 - accuracy: 0.9511 - val_loss: 0.9178 - val_accuracy: 0.8492
# 현재 F1-Score: 0.8360
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.3, 'D_MODEL': 128, 'NUM_LAYERS': 2, 'UNITS': 512}
# Epoch 1/10
# 112/112 [==============================] - 4s 20ms/step - loss: 2.0277 - accuracy: 0.2155 - val_loss: 1.9518 - val_accuracy: 0.3693
# Epoch 2/10
# 112/112 [==============================] - 2s 15ms/step - loss: 1.8974 - accuracy: 0.3297 - val_loss: 1.7360 - val_accuracy: 0.4296
# Epoch 3/10
# 112/112 [==============================] - 2s 15ms/step - loss: 1.5525 - accuracy: 0.4721 - val_loss: 1.4280 - val_accuracy: 0.4874
# Epoch 4/10
# 112/112 [==============================] - 2s 15ms/step - loss: 1.3032 - accuracy: 0.6108 - val_loss: 1.0555 - val_accuracy: 0.7563
# Epoch 5/10
# 112/112 [==============================] - 2s 15ms/step - loss: 0.9971 - accuracy: 0.7499 - val_loss: 0.9457 - val_accuracy: 0.7839
# Epoch 6/10
# 112/112 [==============================] - 2s 15ms/step - loss: 0.8018 - accuracy: 0.8180 - val_loss: 0.8597 - val_accuracy: 0.8166
# Epoch 7/10
# 112/112 [==============================] - 2s 15ms/step - loss: 0.6263 - accuracy: 0.8892 - val_loss: 0.8830 - val_accuracy: 0.8241
# Epoch 8/10
# 112/112 [==============================] - 2s 15ms/step - loss: 0.5034 - accuracy: 0.9291 - val_loss: 0.8665 - val_accuracy: 0.8342
# 현재 F1-Score: 0.8385
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.3, 'D_MODEL': 128, 'NUM_LAYERS': 3, 'UNITS': 128}
# Epoch 1/10
# 112/112 [==============================] - 6s 26ms/step - loss: 2.0050 - accuracy: 0.2085 - val_loss: 1.9686 - val_accuracy: 0.3266
# Epoch 2/10
# 112/112 [==============================] - 2s 19ms/step - loss: 1.8930 - accuracy: 0.3289 - val_loss: 1.7519 - val_accuracy: 0.3543
# Epoch 3/10
# 112/112 [==============================] - 2s 19ms/step - loss: 1.5685 - accuracy: 0.4735 - val_loss: 1.4012 - val_accuracy: 0.5276
# Epoch 4/10
# 112/112 [==============================] - 2s 19ms/step - loss: 1.2670 - accuracy: 0.6195 - val_loss: 1.1430 - val_accuracy: 0.6734
# Epoch 5/10
# 112/112 [==============================] - 2s 19ms/step - loss: 1.0035 - accuracy: 0.7501 - val_loss: 0.8822 - val_accuracy: 0.8090
# Epoch 6/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.8057 - accuracy: 0.8294 - val_loss: 0.8536 - val_accuracy: 0.8291
# Epoch 7/10
# 112/112 [==============================] - 2s 19ms/step - loss: 0.6628 - accuracy: 0.8791 - val_loss: 1.1148 - val_accuracy: 0.7538
# Epoch 8/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.5383 - accuracy: 0.9151 - val_loss: 0.8687 - val_accuracy: 0.8518
# 현재 F1-Score: 0.8158
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.3, 'D_MODEL': 128, 'NUM_LAYERS': 3, 'UNITS': 256}
# Epoch 1/10
# 112/112 [==============================] - 6s 26ms/step - loss: 2.1391 - accuracy: 0.2314 - val_loss: 2.1043 - val_accuracy: 0.2764
# Epoch 2/10
# 112/112 [==============================] - 2s 20ms/step - loss: 2.0171 - accuracy: 0.3169 - val_loss: 2.0442 - val_accuracy: 0.3693
# Epoch 3/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.6737 - accuracy: 0.4497 - val_loss: 1.4970 - val_accuracy: 0.5955
# Epoch 4/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.4206 - accuracy: 0.5932 - val_loss: 1.2662 - val_accuracy: 0.6608
# Epoch 5/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.1214 - accuracy: 0.7298 - val_loss: 1.1009 - val_accuracy: 0.7739
# Epoch 6/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.9104 - accuracy: 0.8152 - val_loss: 0.9813 - val_accuracy: 0.8241
# Epoch 7/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.7719 - accuracy: 0.8707 - val_loss: 1.0829 - val_accuracy: 0.8141
# Epoch 8/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.6413 - accuracy: 0.9109 - val_loss: 0.9094 - val_accuracy: 0.8593
# Epoch 9/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.5513 - accuracy: 0.9327 - val_loss: 1.0227 - val_accuracy: 0.8241
# Epoch 10/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.4444 - accuracy: 0.9629 - val_loss: 0.8922 - val_accuracy: 0.8769
# 현재 F1-Score: 0.8703
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.3, 'D_MODEL': 128, 'NUM_LAYERS': 3, 'UNITS': 512}
# Epoch 1/10
# 112/112 [==============================] - 6s 27ms/step - loss: 2.2283 - accuracy: 0.2119 - val_loss: 2.1736 - val_accuracy: 0.3291
# Epoch 2/10
# 112/112 [==============================] - 2s 21ms/step - loss: 2.1103 - accuracy: 0.3280 - val_loss: 2.0005 - val_accuracy: 0.3668
# Epoch 3/10
# 112/112 [==============================] - 2s 21ms/step - loss: 1.7649 - accuracy: 0.4788 - val_loss: 1.5110 - val_accuracy: 0.6658
# Epoch 4/10
# 112/112 [==============================] - 2s 21ms/step - loss: 1.4310 - accuracy: 0.6424 - val_loss: 1.2281 - val_accuracy: 0.7437
# Epoch 5/10
# 112/112 [==============================] - 2s 21ms/step - loss: 1.1407 - accuracy: 0.7719 - val_loss: 1.2063 - val_accuracy: 0.7613
# Epoch 6/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.9394 - accuracy: 0.8425 - val_loss: 1.0814 - val_accuracy: 0.8141
# Epoch 7/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.8255 - accuracy: 0.8788 - val_loss: 0.9437 - val_accuracy: 0.8744
# Epoch 8/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.6973 - accuracy: 0.9129 - val_loss: 0.9338 - val_accuracy: 0.8668
# Epoch 9/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.5653 - accuracy: 0.9464 - val_loss: 0.9857 - val_accuracy: 0.8367
# Epoch 10/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.4831 - accuracy: 0.9634 - val_loss: 0.8847 - val_accuracy: 0.8794
# 현재 F1-Score: 0.8560
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.3, 'D_MODEL': 256, 'NUM_LAYERS': 1, 'UNITS': 128}
# Epoch 1/10
# 112/112 [==============================] - 3s 15ms/step - loss: 1.8050 - accuracy: 0.2169 - val_loss: 1.7334 - val_accuracy: 0.3141
# Epoch 2/10
# 112/112 [==============================] - 1s 12ms/step - loss: 1.7143 - accuracy: 0.3032 - val_loss: 1.6143 - val_accuracy: 0.3668
# Epoch 3/10
# 112/112 [==============================] - 1s 12ms/step - loss: 1.4551 - accuracy: 0.4618 - val_loss: 1.0817 - val_accuracy: 0.6407
# Epoch 4/10
# 112/112 [==============================] - 1s 12ms/step - loss: 1.0510 - accuracy: 0.6499 - val_loss: 0.8901 - val_accuracy: 0.7186
# Epoch 5/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.8065 - accuracy: 0.7566 - val_loss: 0.6662 - val_accuracy: 0.8040
# Epoch 6/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.5728 - accuracy: 0.8526 - val_loss: 0.5694 - val_accuracy: 0.8543
# Epoch 7/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.4261 - accuracy: 0.8992 - val_loss: 0.5775 - val_accuracy: 0.8668
# Epoch 8/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.3148 - accuracy: 0.9411 - val_loss: 0.5831 - val_accuracy: 0.8744
# 현재 F1-Score: 0.8474
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.3, 'D_MODEL': 256, 'NUM_LAYERS': 1, 'UNITS': 256}
# Epoch 1/10
# 112/112 [==============================] - 3s 15ms/step - loss: 1.9102 - accuracy: 0.2060 - val_loss: 1.8360 - val_accuracy: 0.2261
# Epoch 2/10
# 112/112 [==============================] - 1s 12ms/step - loss: 1.8007 - accuracy: 0.3043 - val_loss: 1.6415 - val_accuracy: 0.4171
# Epoch 3/10
# 112/112 [==============================] - 1s 12ms/step - loss: 1.5181 - accuracy: 0.4578 - val_loss: 1.2660 - val_accuracy: 0.5276
# Epoch 4/10
# 112/112 [==============================] - 1s 12ms/step - loss: 1.1518 - accuracy: 0.6463 - val_loss: 0.9640 - val_accuracy: 0.7337
# Epoch 5/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.8827 - accuracy: 0.7487 - val_loss: 0.7587 - val_accuracy: 0.8065
# Epoch 6/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.6354 - accuracy: 0.8562 - val_loss: 0.6375 - val_accuracy: 0.8317
# Epoch 7/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.4741 - accuracy: 0.9084 - val_loss: 0.7072 - val_accuracy: 0.8367
# Epoch 8/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.3742 - accuracy: 0.9336 - val_loss: 0.7568 - val_accuracy: 0.8417
# 현재 F1-Score: 0.8573
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.3, 'D_MODEL': 256, 'NUM_LAYERS': 1, 'UNITS': 512}
# Epoch 1/10
# 112/112 [==============================] - 3s 16ms/step - loss: 1.9780 - accuracy: 0.2083 - val_loss: 1.8841 - val_accuracy: 0.3568
# Epoch 2/10
# 112/112 [==============================] - 1s 12ms/step - loss: 1.8704 - accuracy: 0.3269 - val_loss: 1.6859 - val_accuracy: 0.4146
# Epoch 3/10
# 112/112 [==============================] - 1s 12ms/step - loss: 1.5489 - accuracy: 0.4788 - val_loss: 1.3233 - val_accuracy: 0.5804
# Epoch 4/10
# 112/112 [==============================] - 1s 12ms/step - loss: 1.2018 - accuracy: 0.6346 - val_loss: 1.0589 - val_accuracy: 0.7412
# Epoch 5/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.9200 - accuracy: 0.7730 - val_loss: 0.8136 - val_accuracy: 0.8216
# Epoch 6/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.7093 - accuracy: 0.8445 - val_loss: 0.8147 - val_accuracy: 0.8116
# Epoch 7/10
# 112/112 [==============================] - 1s 12ms/step - loss: 0.5314 - accuracy: 0.9068 - val_loss: 0.8283 - val_accuracy: 0.8342
# 현재 F1-Score: 0.8282
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.3, 'D_MODEL': 256, 'NUM_LAYERS': 2, 'UNITS': 128}
# Epoch 1/10
# 112/112 [==============================] - 5s 24ms/step - loss: 1.9748 - accuracy: 0.2147 - val_loss: 1.8952 - val_accuracy: 0.3166
# Epoch 2/10
# 112/112 [==============================] - 2s 19ms/step - loss: 1.8546 - accuracy: 0.3197 - val_loss: 1.6109 - val_accuracy: 0.4623
# Epoch 3/10
# 112/112 [==============================] - 2s 19ms/step - loss: 1.4882 - accuracy: 0.4972 - val_loss: 1.2443 - val_accuracy: 0.6156
# Epoch 4/10
# 112/112 [==============================] - 2s 19ms/step - loss: 1.1439 - accuracy: 0.6798 - val_loss: 1.0896 - val_accuracy: 0.7362
# Epoch 5/10
# 112/112 [==============================] - 2s 19ms/step - loss: 0.8991 - accuracy: 0.7772 - val_loss: 0.8787 - val_accuracy: 0.8090
# Epoch 6/10
# 112/112 [==============================] - 2s 19ms/step - loss: 0.6816 - accuracy: 0.8607 - val_loss: 0.8958 - val_accuracy: 0.8166
# Epoch 7/10
# 112/112 [==============================] - 2s 19ms/step - loss: 0.5510 - accuracy: 0.9082 - val_loss: 0.8164 - val_accuracy: 0.8492
# Epoch 8/10
# 112/112 [==============================] - 2s 19ms/step - loss: 0.4339 - accuracy: 0.9481 - val_loss: 1.0740 - val_accuracy: 0.8166
# Epoch 9/10
# ...
# Epoch 10/10
# 112/112 [==============================] - 3s 27ms/step - loss: 0.6287 - accuracy: 0.9090 - val_loss: 1.0439 - val_accuracy: 0.8518
# 현재 F1-Score: 0.8489
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.5, 'D_MODEL': 256, 'NUM_LAYERS': 3, 'UNITS': 256}
# Epoch 1/10
# 112/112 [==============================] - 7s 34ms/step - loss: 2.4110 - accuracy: 0.2027 - val_loss: 2.3675 - val_accuracy: 0.2362
# Epoch 2/10
# 112/112 [==============================] - 3s 28ms/step - loss: 2.3288 - accuracy: 0.2783 - val_loss: 2.2727 - val_accuracy: 0.3693
# Epoch 3/10
# 112/112 [==============================] - 3s 28ms/step - loss: 2.0872 - accuracy: 0.4104 - val_loss: 1.9022 - val_accuracy: 0.4472
# Epoch 4/10
# 112/112 [==============================] - 3s 28ms/step - loss: 1.7950 - accuracy: 0.5223 - val_loss: 1.8335 - val_accuracy: 0.5151
# Epoch 5/10
# 112/112 [==============================] - 3s 28ms/step - loss: 1.5403 - accuracy: 0.6516 - val_loss: 1.4730 - val_accuracy: 0.7487
# Epoch 6/10
# 112/112 [==============================] - 3s 28ms/step - loss: 1.3503 - accuracy: 0.7275 - val_loss: 1.4705 - val_accuracy: 0.7538
# Epoch 7/10
# 112/112 [==============================] - 3s 28ms/step - loss: 1.1899 - accuracy: 0.7990 - val_loss: 1.1308 - val_accuracy: 0.8492
# Epoch 8/10
# 112/112 [==============================] - 3s 29ms/step - loss: 1.0145 - accuracy: 0.8587 - val_loss: 1.2139 - val_accuracy: 0.8342
# Epoch 9/10
# 112/112 [==============================] - 3s 28ms/step - loss: 0.8868 - accuracy: 0.8948 - val_loss: 1.0970 - val_accuracy: 0.8568
# Epoch 10/10
# 112/112 [==============================] - 3s 28ms/step - loss: 0.7641 - accuracy: 0.9221 - val_loss: 1.4603 - val_accuracy: 0.8015
# 현재 F1-Score: 0.8064
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.5, 'D_MODEL': 256, 'NUM_LAYERS': 3, 'UNITS': 512}
# Epoch 1/10
# 112/112 [==============================] - 8s 40ms/step - loss: 2.6736 - accuracy: 0.2058 - val_loss: 2.5631 - val_accuracy: 0.2864
# Epoch 2/10
# 112/112 [==============================] - 3s 31ms/step - loss: 2.5575 - accuracy: 0.2903 - val_loss: 2.4326 - val_accuracy: 0.3744
# Epoch 3/10
# 112/112 [==============================] - 3s 31ms/step - loss: 2.2753 - accuracy: 0.4255 - val_loss: 2.0948 - val_accuracy: 0.5754
# Epoch 4/10
# 112/112 [==============================] - 3s 30ms/step - loss: 2.0158 - accuracy: 0.5430 - val_loss: 1.8392 - val_accuracy: 0.6357
# Epoch 5/10
# 112/112 [==============================] - 3s 31ms/step - loss: 1.7903 - accuracy: 0.6474 - val_loss: 1.7111 - val_accuracy: 0.7211
# Epoch 6/10
# 112/112 [==============================] - 3s 31ms/step - loss: 1.5991 - accuracy: 0.7172 - val_loss: 1.5586 - val_accuracy: 0.7814
# Epoch 7/10
# 112/112 [==============================] - 3s 31ms/step - loss: 1.4022 - accuracy: 0.7870 - val_loss: 1.6346 - val_accuracy: 0.7814
# Epoch 8/10
# 112/112 [==============================] - 3s 31ms/step - loss: 1.2691 - accuracy: 0.8275 - val_loss: 1.3401 - val_accuracy: 0.8342
# Epoch 9/10
# 112/112 [==============================] - 3s 31ms/step - loss: 1.0941 - accuracy: 0.8719 - val_loss: 1.2531 - val_accuracy: 0.8467
# Epoch 10/10
# 112/112 [==============================] - 3s 31ms/step - loss: 0.9445 - accuracy: 0.9070 - val_loss: 1.2809 - val_accuracy: 0.8593
# 현재 F1-Score: 0.8630
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.5, 'D_MODEL': 512, 'NUM_LAYERS': 1, 'UNITS': 128}
# Epoch 1/10
# 112/112 [==============================] - 4s 23ms/step - loss: 1.8594 - accuracy: 0.2038 - val_loss: 1.7679 - val_accuracy: 0.2814
# Epoch 2/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.7671 - accuracy: 0.2903 - val_loss: 1.6492 - val_accuracy: 0.3492
# Epoch 3/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.5245 - accuracy: 0.4470 - val_loss: 1.2515 - val_accuracy: 0.5879
# Epoch 4/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.1890 - accuracy: 0.5958 - val_loss: 1.1125 - val_accuracy: 0.6834
# Epoch 5/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.0234 - accuracy: 0.6672 - val_loss: 1.0914 - val_accuracy: 0.7236
# Epoch 6/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.8618 - accuracy: 0.7393 - val_loss: 0.8810 - val_accuracy: 0.7789
# Epoch 7/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.7063 - accuracy: 0.8093 - val_loss: 0.8136 - val_accuracy: 0.8015
# Epoch 8/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.5734 - accuracy: 0.8554 - val_loss: 0.7156 - val_accuracy: 0.8467
# Epoch 9/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.4559 - accuracy: 0.8964 - val_loss: 0.8051 - val_accuracy: 0.8568
# Epoch 10/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.3652 - accuracy: 0.9294 - val_loss: 0.7865 - val_accuracy: 0.8693
# 현재 F1-Score: 0.8484
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.5, 'D_MODEL': 512, 'NUM_LAYERS': 1, 'UNITS': 256}
# Epoch 1/10
# 112/112 [==============================] - 4s 23ms/step - loss: 2.0131 - accuracy: 0.2083 - val_loss: 1.9499 - val_accuracy: 0.2211
# Epoch 2/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.9038 - accuracy: 0.2934 - val_loss: 1.7650 - val_accuracy: 0.4095
# Epoch 3/10
# 112/112 [==============================] - 2s 21ms/step - loss: 1.6618 - accuracy: 0.4389 - val_loss: 1.3999 - val_accuracy: 0.6005
# Epoch 4/10
# 112/112 [==============================] - 2s 21ms/step - loss: 1.3383 - accuracy: 0.5851 - val_loss: 1.2544 - val_accuracy: 0.6583
# Epoch 5/10
# 112/112 [==============================] - 2s 20ms/step - loss: 1.1617 - accuracy: 0.6611 - val_loss: 1.1778 - val_accuracy: 0.7236
# Epoch 6/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.9807 - accuracy: 0.7404 - val_loss: 1.0270 - val_accuracy: 0.7714
# Epoch 7/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.8238 - accuracy: 0.8021 - val_loss: 0.9235 - val_accuracy: 0.8065
# Epoch 8/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.6938 - accuracy: 0.8529 - val_loss: 0.8815 - val_accuracy: 0.8342
# Epoch 9/10
# 112/112 [==============================] - 2s 20ms/step - loss: 0.5606 - accuracy: 0.8973 - val_loss: 0.8503 - val_accuracy: 0.8342
# Epoch 10/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.4643 - accuracy: 0.9263 - val_loss: 0.8853 - val_accuracy: 0.8467
# 현재 F1-Score: 0.8607
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.5, 'D_MODEL': 512, 'NUM_LAYERS': 1, 'UNITS': 512}
# Epoch 1/10
# 112/112 [==============================] - 4s 24ms/step - loss: 2.2130 - accuracy: 0.2097 - val_loss: 2.1232 - val_accuracy: 0.2286
# Epoch 2/10
# 112/112 [==============================] - 2s 21ms/step - loss: 2.0707 - accuracy: 0.2848 - val_loss: 2.0283 - val_accuracy: 0.3417
# Epoch 3/10
# 112/112 [==============================] - 2s 21ms/step - loss: 1.8240 - accuracy: 0.4389 - val_loss: 1.5480 - val_accuracy: 0.5804
# Epoch 4/10
# 112/112 [==============================] - 2s 22ms/step - loss: 1.5065 - accuracy: 0.5698 - val_loss: 1.4601 - val_accuracy: 0.6508
# Epoch 5/10
# 112/112 [==============================] - 2s 22ms/step - loss: 1.3134 - accuracy: 0.6533 - val_loss: 1.2699 - val_accuracy: 0.7111
# Epoch 6/10
# 112/112 [==============================] - 2s 22ms/step - loss: 1.1267 - accuracy: 0.7337 - val_loss: 1.0984 - val_accuracy: 0.7789
# Epoch 7/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.9548 - accuracy: 0.8037 - val_loss: 0.9954 - val_accuracy: 0.8417
# Epoch 8/10
# 112/112 [==============================] - 2s 22ms/step - loss: 0.8054 - accuracy: 0.8613 - val_loss: 0.9003 - val_accuracy: 0.8693
# Epoch 9/10
# 112/112 [==============================] - 2s 21ms/step - loss: 0.6684 - accuracy: 0.9031 - val_loss: 0.9458 - val_accuracy: 0.8593
# Epoch 10/10
# 112/112 [==============================] - 2s 22ms/step - loss: 0.5692 - accuracy: 0.9221 - val_loss: 0.9702 - val_accuracy: 0.8593
# 현재 F1-Score: 0.8581
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.5, 'D_MODEL': 512, 'NUM_LAYERS': 2, 'UNITS': 128}
# Epoch 1/10
# 112/112 [==============================] - 7s 39ms/step - loss: 2.0580 - accuracy: 0.2306 - val_loss: 1.9217 - val_accuracy: 0.4045
# Epoch 2/10
# 112/112 [==============================] - 4s 34ms/step - loss: 1.9269 - accuracy: 0.3264 - val_loss: 1.8726 - val_accuracy: 0.4246
# Epoch 3/10
# 112/112 [==============================] - 4s 35ms/step - loss: 1.6135 - accuracy: 0.4765 - val_loss: 1.3560 - val_accuracy: 0.6256
# Epoch 4/10
# 112/112 [==============================] - 4s 35ms/step - loss: 1.3395 - accuracy: 0.6133 - val_loss: 1.2179 - val_accuracy: 0.7010
# Epoch 5/10
# 112/112 [==============================] - 4s 35ms/step - loss: 1.1498 - accuracy: 0.7002 - val_loss: 1.0486 - val_accuracy: 0.7513
# Epoch 6/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.9726 - accuracy: 0.7694 - val_loss: 1.0820 - val_accuracy: 0.7764
# Epoch 7/10
# 112/112 [==============================] - 4s 35ms/step - loss: 0.8287 - accuracy: 0.8264 - val_loss: 1.0577 - val_accuracy: 0.8216
# 현재 F1-Score: 0.7654
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.5, 'D_MODEL': 512, 'NUM_LAYERS': 2, 'UNITS': 256}
# Epoch 1/10
# 112/112 [==============================] - 7s 41ms/step - loss: 2.3358 - accuracy: 0.2236 - val_loss: 2.2374 - val_accuracy: 0.3216
# Epoch 2/10
# 112/112 [==============================] - 4s 36ms/step - loss: 2.2006 - accuracy: 0.3146 - val_loss: 2.1797 - val_accuracy: 0.4347
# Epoch 3/10
# 112/112 [==============================] - 4s 36ms/step - loss: 1.8617 - accuracy: 0.4905 - val_loss: 1.7047 - val_accuracy: 0.5704
# Epoch 4/10
# 112/112 [==============================] - 4s 36ms/step - loss: 1.5845 - accuracy: 0.6156 - val_loss: 1.7079 - val_accuracy: 0.6533
# Epoch 5/10
# 112/112 [==============================] - 4s 36ms/step - loss: 1.3979 - accuracy: 0.6946 - val_loss: 1.3322 - val_accuracy: 0.7638
# Epoch 6/10
# 112/112 [==============================] - 4s 36ms/step - loss: 1.2121 - accuracy: 0.7716 - val_loss: 1.1376 - val_accuracy: 0.8266
# Epoch 7/10
# 112/112 [==============================] - 4s 36ms/step - loss: 1.0482 - accuracy: 0.8336 - val_loss: 1.1639 - val_accuracy: 0.8417
# Epoch 8/10
# 112/112 [==============================] - 4s 36ms/step - loss: 0.9141 - accuracy: 0.8808 - val_loss: 1.1530 - val_accuracy: 0.8392
# 현재 F1-Score: 0.8143
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.5, 'D_MODEL': 512, 'NUM_LAYERS': 2, 'UNITS': 512}
# Epoch 1/10
# 112/112 [==============================] - 7s 43ms/step - loss: 2.6660 - accuracy: 0.2365 - val_loss: 2.5634 - val_accuracy: 0.3643
# Epoch 2/10
# 112/112 [==============================] - 4s 39ms/step - loss: 2.5321 - accuracy: 0.3171 - val_loss: 2.3404 - val_accuracy: 0.4673
# Epoch 3/10
# 112/112 [==============================] - 4s 39ms/step - loss: 2.1889 - accuracy: 0.4919 - val_loss: 1.9398 - val_accuracy: 0.6432
# Epoch 4/10
# 112/112 [==============================] - 4s 39ms/step - loss: 1.9192 - accuracy: 0.6161 - val_loss: 1.8118 - val_accuracy: 0.6910
# Epoch 5/10
# 112/112 [==============================] - 4s 39ms/step - loss: 1.7443 - accuracy: 0.6829 - val_loss: 1.8752 - val_accuracy: 0.6960
# Epoch 6/10
# 112/112 [==============================] - 4s 39ms/step - loss: 1.5587 - accuracy: 0.7594 - val_loss: 1.6020 - val_accuracy: 0.8065
# Epoch 7/10
# 112/112 [==============================] - 4s 39ms/step - loss: 1.3342 - accuracy: 0.8347 - val_loss: 1.5798 - val_accuracy: 0.8266
# Epoch 8/10
# 112/112 [==============================] - 4s 39ms/step - loss: 1.1863 - accuracy: 0.8760 - val_loss: 1.4510 - val_accuracy: 0.8342
# Epoch 9/10
# 112/112 [==============================] - 4s 39ms/step - loss: 1.0454 - accuracy: 0.9070 - val_loss: 1.5684 - val_accuracy: 0.8417
# Epoch 10/10
# 112/112 [==============================] - 4s 39ms/step - loss: 0.8938 - accuracy: 0.9366 - val_loss: 1.3301 - val_accuracy: 0.8618
# 현재 F1-Score: 0.8614
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.5, 'D_MODEL': 512, 'NUM_LAYERS': 3, 'UNITS': 128}
# Epoch 1/10
# 112/112 [==============================] - 9s 55ms/step - loss: 2.3043 - accuracy: 0.2088 - val_loss: 2.2204 - val_accuracy: 0.3040
# Epoch 2/10
# 112/112 [==============================] - 6s 49ms/step - loss: 2.1467 - accuracy: 0.3146 - val_loss: 2.2868 - val_accuracy: 0.3819
# Epoch 3/10
# 112/112 [==============================] - 6s 49ms/step - loss: 1.8418 - accuracy: 0.4676 - val_loss: 1.6140 - val_accuracy: 0.5879
# Epoch 4/10
# 112/112 [==============================] - 6s 49ms/step - loss: 1.5384 - accuracy: 0.6022 - val_loss: 1.4385 - val_accuracy: 0.6935
# Epoch 5/10
# 112/112 [==============================] - 6s 50ms/step - loss: 1.3817 - accuracy: 0.6815 - val_loss: 1.2971 - val_accuracy: 0.7714
# Epoch 6/10
# 112/112 [==============================] - 6s 50ms/step - loss: 1.2001 - accuracy: 0.7661 - val_loss: 1.2595 - val_accuracy: 0.7789
# Epoch 7/10
# 112/112 [==============================] - 6s 50ms/step - loss: 1.0534 - accuracy: 0.8107 - val_loss: 1.0527 - val_accuracy: 0.8317
# Epoch 8/10
# 112/112 [==============================] - 6s 50ms/step - loss: 0.8970 - accuracy: 0.8716 - val_loss: 1.2362 - val_accuracy: 0.8191
# Epoch 9/10
# 112/112 [==============================] - 6s 49ms/step - loss: 0.7893 - accuracy: 0.8998 - val_loss: 1.3785 - val_accuracy: 0.8442
# 현재 F1-Score: 0.8478
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.5, 'D_MODEL': 512, 'NUM_LAYERS': 3, 'UNITS': 256}
# Epoch 1/10
# 112/112 [==============================] - 10s 58ms/step - loss: 2.6897 - accuracy: 0.2150 - val_loss: 2.5310 - val_accuracy: 0.3191
# Epoch 2/10
# 112/112 [==============================] - 6s 52ms/step - loss: 2.5445 - accuracy: 0.3085 - val_loss: 2.3313 - val_accuracy: 0.4698
# Epoch 3/10
# 112/112 [==============================] - 6s 52ms/step - loss: 2.2051 - accuracy: 0.4726 - val_loss: 2.0216 - val_accuracy: 0.6131
# Epoch 4/10
# 112/112 [==============================] - 6s 52ms/step - loss: 1.9344 - accuracy: 0.6108 - val_loss: 1.8782 - val_accuracy: 0.6759
# Epoch 5/10
# 112/112 [==============================] - 6s 52ms/step - loss: 1.7118 - accuracy: 0.7060 - val_loss: 1.7704 - val_accuracy: 0.7437
# Epoch 6/10
# 112/112 [==============================] - 6s 52ms/step - loss: 1.5332 - accuracy: 0.7616 - val_loss: 1.6509 - val_accuracy: 0.8040
# Epoch 7/10
# 112/112 [==============================] - 6s 52ms/step - loss: 1.3934 - accuracy: 0.8155 - val_loss: 1.6890 - val_accuracy: 0.7965
# Epoch 8/10
# 112/112 [==============================] - 6s 52ms/step - loss: 1.2268 - accuracy: 0.8727 - val_loss: 1.6587 - val_accuracy: 0.8116
# 현재 F1-Score: 0.7845
# 현재 하이퍼파라미터 조합: {'DROPOUT': 0.5, 'D_MODEL': 512, 'NUM_LAYERS': 3, 'UNITS': 512}
# Epoch 1/10
# 112/112 [==============================] - 10s 61ms/step - loss: 3.1819 - accuracy: 0.2359 - val_loss: 3.0861 - val_accuracy: 0.3266
# Epoch 2/10
# 112/112 [==============================] - 6s 56ms/step - loss: 3.0387 - accuracy: 0.3132 - val_loss: 2.9400 - val_accuracy: 0.4648
# Epoch 3/10
# 112/112 [==============================] - 6s 56ms/step - loss: 2.6750 - accuracy: 0.5089 - val_loss: 2.4276 - val_accuracy: 0.6583
# Epoch 4/10
# 112/112 [==============================] - 6s 57ms/step - loss: 2.3990 - accuracy: 0.6175 - val_loss: 2.3795 - val_accuracy: 0.6784
# Epoch 5/10
# 112/112 [==============================] - 6s 57ms/step - loss: 2.2085 - accuracy: 0.6876 - val_loss: 2.0983 - val_accuracy: 0.7714
# Epoch 6/10
# 112/112 [==============================] - 6s 56ms/step - loss: 2.0256 - accuracy: 0.7577 - val_loss: 1.9796 - val_accuracy: 0.8040
# Epoch 7/10
# 112/112 [==============================] - 6s 56ms/step - loss: 1.8313 - accuracy: 0.8180 - val_loss: 1.8713 - val_accuracy: 0.8417
# Epoch 8/10
# 112/112 [==============================] - 6s 56ms/step - loss: 1.6280 - accuracy: 0.8680 - val_loss: 1.6961 - val_accuracy: 0.8593
# Epoch 9/10
# 112/112 [==============================] - 6s 56ms/step - loss: 1.4379 - accuracy: 0.9112 - val_loss: 1.6936 - val_accuracy: 0.8467
# Epoch 10/10
# 112/112 [==============================] - 6s 56ms/step - loss: 1.3107 - accuracy: 0.9185 - val_loss: 1.5889 - val_accuracy: 0.8618
# 현재 F1-Score: 0.8805
# 최고의 F1-Score: 0.8805
# 최적의 하이퍼파라미터: {'DROPOUT': 0.5, 'D_MODEL': 512, 'NUM_LAYERS': 3, 'UNITS': 512}

# %%
from sklearn.metrics import f1_score
from sklearn.model_selection import ParameterGrid

VOCAB_SIZE = 10000
NUM_LAYERS = 3
D_MODEL = 512
NUM_HEADS = 8
UNITS = 512
DROPOUT = 0.5

model = transformer(vocab_size=VOCAB_SIZE, 
                    num_layers=NUM_LAYERS, 
                    units=UNITS, 
                    d_model=D_MODEL, 
                    num_heads=NUM_HEADS, 
                    dropout=DROPOUT)
model.summary()
# Out:
# Model: "transformer"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# inputs (InputLayer)             [(None, None)]       0
# __________________________________________________________________________________________________
# enc_padding_mask (Lambda)       (None, 1, 1, None)   0           inputs[0][0]
# __________________________________________________________________________________________________
# encoder (Functional)            (None, None, 512)    9853952     inputs[0][0]
#                                                                  enc_padding_mask[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_97 (Gl (None, 512)          0           encoder[0][0]
# __________________________________________________________________________________________________
# dropout_583 (Dropout)           (None, 512)          0           global_average_pooling1d_97[0][0]
# __________________________________________________________________________________________________
# linear_hidden_layer (Dense)     (None, 1028)         527364      dropout_583[0][0]
# __________________________________________________________________________________________________
# outputs (Dense)                 (None, 5)            5145        linear_hidden_layer[0][0]
# ==================================================================================================
# Total params: 10,386,461
# Trainable params: 10,386,461
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def loss_function(y_true, y_pred):
    y_true = tf.squeeze(y_true, axis=-1)
    return tf.reduce_mean(tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False)(y_true, y_pred))

# %%
def accuracy(y_true, y_pred):
    return tf.keras.metrics.sparse_categorical_accuracy(y_true, y_pred)

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, d_model, warmup_steps=4000):
        super(CustomSchedule, self).__init__()
        self.d_model = d_model
        self.d_model = tf.cast(self.d_model, tf.float32)
        self.warmup_steps = warmup_steps
    def __call__(self, step):
        arg1 = tf.math.rsqrt(step)
        arg2 = step * (self.warmup_steps**-1.5)
        return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(D_MODEL)
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate, 
                                     beta_1=0.9, beta_2=0.98, epsilon=1e-9)

model.compile(optimizer=optimizer, loss=loss_function, metrics=[accuracy])

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', 
                               patience=2, 
                               restore_best_weights=True)

# %%
from sklearn.metrics import f1_score

# 모델 학습 중 F1-score를 모니터링하는 callback 생성
class F1ScoreCallback(tf.keras.callbacks.Callback):
    def __init__(self, val_data):
        super(F1ScoreCallback, self).__init__()
        self.val_data = val_data

    def on_epoch_end(self, epoch, logs=None):
        val_predict = np.argmax(self.model.predict(self.val_data), axis=-1)
        val_targ = np.concatenate([y for x, y in self.val_data], axis=0)
        _val_f1 = f1_score(val_targ, val_predict, average='weighted')
        print(f'\nEpoch {epoch+1}: F1-Score = {_val_f1:.4f}')
        logs['f1_score'] = _val_f1

# %%
# 클래스 가중치를 모델에 반영한 학습
EPOCHS = 100
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCHS,
    verbose=1,
    class_weight=class_weights,  # 클래스 가중치 반영
    callbacks=[early_stopping, F1ScoreCallback(val_dataset)]  # F1-score 모니터링 추가
)
# Out:
# Epoch 1/100
#   6/112 [>.............................] - ETA: 6s - loss: 3.2664 - accuracy: 0.1823WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0293s vs `on_train_batch_end` time: 0.0317s). Check your callbacks.
# 112/112 [==============================] - 10s 61ms/step - loss: 3.1921 - accuracy: 0.2259 - val_loss: 3.0796 - val_accuracy: 0.3568
#
# Epoch 1: F1-Score = 0.2715
# Epoch 2/100
# 112/112 [==============================] - 6s 56ms/step - loss: 3.0601 - accuracy: 0.3046 - val_loss: 2.9154 - val_accuracy: 0.3970
#
# Epoch 2: F1-Score = 0.3054
# Epoch 3/100
# 112/112 [==============================] - 6s 56ms/step - loss: 2.7538 - accuracy: 0.4450 - val_loss: 2.5100 - val_accuracy: 0.6005
#
# Epoch 3: F1-Score = 0.5953
# Epoch 4/100
# 112/112 [==============================] - 6s 56ms/step - loss: 2.4378 - accuracy: 0.5958 - val_loss: 2.2271 - val_accuracy: 0.7437
#
# Epoch 4: F1-Score = 0.7385
# Epoch 5/100
# 112/112 [==============================] - 6s 57ms/step - loss: 2.2095 - accuracy: 0.7013 - val_loss: 2.2184 - val_accuracy: 0.7613
#
# Epoch 5: F1-Score = 0.7542
# Epoch 6/100
# 112/112 [==============================] - 6s 57ms/step - loss: 1.9894 - accuracy: 0.7733 - val_loss: 1.9840 - val_accuracy: 0.8266
#
# Epoch 6: F1-Score = 0.8249
# Epoch 7/100
# 112/112 [==============================] - 6s 56ms/step - loss: 1.7996 - accuracy: 0.8289 - val_loss: 2.2231 - val_accuracy: 0.7839
#
# Epoch 7: F1-Score = 0.7793
# Epoch 8/100
# 112/112 [==============================] - 6s 56ms/step - loss: 1.6085 - accuracy: 0.8791 - val_loss: 1.8843 - val_accuracy: 0.8593
#
# Epoch 8: F1-Score = 0.8564
# Epoch 9/100
# 112/112 [==============================] - 6s 56ms/step - loss: 1.4477 - accuracy: 0.9054 - val_loss: 1.8569 - val_accuracy: 0.8291
#
# Epoch 9: F1-Score = 0.8276
# Epoch 10/100
# 112/112 [==============================] - 6s 55ms/step - loss: 1.3276 - accuracy: 0.9179 - val_loss: 1.7025 - val_accuracy: 0.8467
#
# Epoch 10: F1-Score = 0.8474
# Epoch 11/100
# 112/112 [==============================] - 6s 55ms/step - loss: 1.1608 - accuracy: 0.9417 - val_loss: 1.6266 - val_accuracy: 0.8568
#
# Epoch 11: F1-Score = 0.8553
# Epoch 12/100
# 112/112 [==============================] - 6s 55ms/step - loss: 1.0331 - accuracy: 0.9456 - val_loss: 1.4887 - val_accuracy: 0.8693
#
# Epoch 12: F1-Score = 0.8698
# Epoch 13/100
# 112/112 [==============================] - 6s 55ms/step - loss: 0.9005 - accuracy: 0.9534 - val_loss: 1.4553 - val_accuracy: 0.8568
#
# Epoch 13: F1-Score = 0.8549
# Epoch 14/100
# 112/112 [==============================] - 6s 56ms/step - loss: 0.7693 - accuracy: 0.9623 - val_loss: 1.4471 - val_accuracy: 0.8618
#
# Epoch 14: F1-Score = 0.8617
# Epoch 15/100
# 112/112 [==============================] - 6s 56ms/step - loss: 0.6274 - accuracy: 0.9712 - val_loss: 1.3229 - val_accuracy: 0.8719
#
# Epoch 15: F1-Score = 0.8709
# Epoch 16/100
# 112/112 [==============================] - 6s 56ms/step - loss: 0.5568 - accuracy: 0.9665 - val_loss: 1.7251 - val_accuracy: 0.8266
#
# Epoch 16: F1-Score = 0.8205
# Epoch 17/100
# 112/112 [==============================] - 6s 56ms/step - loss: 0.4596 - accuracy: 0.9729 - val_loss: 1.3143 - val_accuracy: 0.8492
#
# Epoch 17: F1-Score = 0.8482
# Epoch 18/100
# 112/112 [==============================] - 6s 56ms/step - loss: 0.3770 - accuracy: 0.9774 - val_loss: 1.0727 - val_accuracy: 0.8668
#
# Epoch 18: F1-Score = 0.8653
# Epoch 19/100
# 112/112 [==============================] - 6s 56ms/step - loss: 0.3178 - accuracy: 0.9782 - val_loss: 1.2363 - val_accuracy: 0.8568
#
# Epoch 19: F1-Score = 0.8568
# Epoch 20/100
# 112/112 [==============================] - 6s 56ms/step - loss: 0.2773 - accuracy: 0.9785 - val_loss: 0.9528 - val_accuracy: 0.8568
#
# Epoch 20: F1-Score = 0.8567
# Epoch 21/100
# 112/112 [==============================] - 6s 56ms/step - loss: 0.1984 - accuracy: 0.9899 - val_loss: 1.2222 - val_accuracy: 0.8216
#
# Epoch 21: F1-Score = 0.8236
# Epoch 22/100
# 112/112 [==============================] - 6s 56ms/step - loss: 0.1807 - accuracy: 0.9860 - val_loss: 1.4121 - val_accuracy: 0.8342
#
# Epoch 22: F1-Score = 0.8567

# %%
import matplotlib.pyplot as plt

# 정확한 val_loss 및 val_accuracy 플롯
fig, axs = plt.subplots(2, 1, figsize=(12, 12))

# Train/Val Loss Plot
axs[0].plot(history.history['loss'], label='Train Loss')
axs[0].plot(history.history['val_loss'], label='Validation Loss')
axs[0].set_title('Loss')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Loss')
axs[0].legend()

# Train/Val Accuracy Plot
axs[1].plot(history.history['accuracy'], label='Train Accuracy')
axs[1].plot(history.history['val_accuracy'], label='Validation Accuracy')
axs[1].set_title('Accuracy')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Accuracy')
axs[1].legend()

plt.show()

# %%
model.evaluate(val_dataset)
# Out:
# 13/13 [==============================] - 0s 19ms/step - loss: 0.9528 - accuracy: 0.8568
# [0.9527984857559204, 0.856783926486969]

# %% [markdown]
# # 하이퍼 파라미터 튜닝용

# %%
sweep_config = {
    "name": "sweep_test_nlp",
    "metric": {"name": "val_loss", "goal": "minimize"},
    "method": "random",
    "parameters": {

        "epoch" : {
            "distribution" : "int_uniform",
            "min" : 5,
            "max" : 10
            },
        
        "drop_out" : {
            "min": 0.1,
            "max": 0.4
        }
                    
        }
    }

# %% [markdown]
# # Submission

# %%
import os
import sys
sys.path.append("../")

## 경고 무시
import warnings
warnings.filterwarnings('ignore')

## 시각화 툴
import matplotlib.pyplot as plt
import seaborn as sns

## encoding 
from sklearn.preprocessing import LabelEncoder

## vocabulary
import tensorflow_datasets as tfds

## preprocessor
from custom_preprocessor import Preprocessor

# %%
preprocessor = Preprocessor()

# %%
preprocessed_train, preprocessed_test = preprocessor.preprocess()

# %%
# test 데이터셋 불러와서 text 부분 tokenize 진행
text = preprocessed_test['text']
test_tensor, tokenizer = tokenize(text)

# %%
# 크기 확인
test_tensor.shape
# Out:
# (500, 100)

# %%
import os
from os.path import join

def save_submission(y_pred, user_name, f1_score=None):
    data_path = "/aiffel/aiffel/dlthon_team5/data"
    save_path = "../submission"
    
    # 기존 submission 불러오기
    submission_path = join(data_path, 'new_submission.csv')
    submission = pd.read_csv(submission_path)
    
    # 예측 클래스 저장
    submission['class'] = y_pred
    
    # F1-Score를 파일명에 반영
    submission_csv_path = '{}/submission_{}_f1score_{:.4f}.csv'.format(save_path, user_name, f1_score)
    submission.to_csv(submission_csv_path, index=False)
    print('{} saved!'.format(submission_csv_path))

# %%
# 뒤쪽 str값은 본인 이니셜과 버전을 작성하면됨
# F1-Score를 포함하여 submission 파일 저장

save_submission(y_pred, 'hsv_v2', 0.8568)
# Out:
# ../submission/submission_hsv_v2_f1score_0.8568.csv saved!
